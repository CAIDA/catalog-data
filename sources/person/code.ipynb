# %% [markdown]
# 9/18/2024
# - write a script to generate JSON file for each person entry
#
#
# https://github.com/CAIDA/catalog-data/issues/814

# %%
people = [
    {
        "id": "person:jones__michael",
        "organizations": [
            "MIT"
        ],
        "nameLast": "Jones",
        "nameFirst": "Michael",
        "name": "Jones, Michael"
    },
    {
        "id": "person:kepner__jeremy",
        "organizations": [
            "MIT"
        ],
        "nameLast": "Kepner",
        "nameFirst": "Jeremy",
        "name": "Kepner, Jeremy"
    },
    {
        "id": "person:prout__andrew",
        "organizations": [
            "MIT"
        ],
        "nameLast": "Prout",
        "nameFirst": "Andrew",
        "name": "Prout, Andrew"
    },
    {
        "id": "person:davis__timothy",
        "organizations": [
            "MIT"
        ],
        "nameLast": "Davis",
        "nameFirst": "Timothy",
        "name": "Davis, Timothy"
    },
    {
        "id": "person:arcand__william",
        "organizations": [
            "MIT"
        ],
        "nameLast": "Arcand",
        "nameFirst": "William",
        "name": "Arcand, William"
    },
    {
        "id": "person:bestor__david",
        "organizations": [
            "MIT"
        ],
        "nameLast": "Bestor",
        "nameFirst": "David",
        "name": "Bestor, David"
    },
    {
        "id": "person:bergeron__william",
        "organizations": [
            "MIT"
        ],
        "nameLast": "Bergeron",
        "nameFirst": "William",
        "name": "Bergeron, William"
    },
    {
        "id": "person:byun__chansup",
        "organizations": [
            "MIT"
        ],
        "nameLast": "Byun",
        "nameFirst": "Chansup",
        "name": "Byun, Chansup"
    },
    {
        "id": "person:gadepally__vijay",
        "organizations": [
            "MIT"
        ],
        "nameLast": "Gadepally",
        "nameFirst": "Vijay",
        "name": "Gadepally, Vijay"
    },
    {
        "id": "person:houle__micheal",
        "organizations": [
            "MIT"
        ],
        "nameLast": "Houle",
        "nameFirst": "Micheal",
        "name": "Houle, Micheal"
    },
    {
        "id": "person:hubbell__matthew",
        "organizations": [
            "MIT"
        ],
        "nameLast": "Hubbell",
        "nameFirst": "Matthew",
        "name": "Hubbell, Matthew"
    },
    {
        "id": "person:jananthan__hayden",
        "organizations": [
            "MIT"
        ],
        "nameLast": "Jananthan",
        "nameFirst": "Hayden",
        "name": "Jananthan, Hayden"
    },
    {
        "id": "person:klein__anna",
        "organizations": [
            "MIT"
        ],
        "nameLast": "Klein",
        "nameFirst": "Anna",
        "name": "Klein, Anna"
    },
    {
        "id": "person:milechin__lauren",
        "organizations": [
            "MIT"
        ],
        "nameLast": "Milechin",
        "nameFirst": "Lauren",
        "name": "Milechin, Lauren"
    },
    {
        "id": "person:morales__guillermo",
        "organizations": [
            "MIT"
        ],
        "nameLast": "Morales",
        "nameFirst": "Guillermo",
        "name": "Morales, Guillermo"
    },
    {
        "id": "person:mullen__julie",
        "organizations": [
            "MIT"
        ],
        "nameLast": "Mullen",
        "nameFirst": "Julie",
        "name": "Mullen, Julie"
    },
    {
        "id": "person:patel__ritesh",
        "organizations": [
            "MIT"
        ],
        "nameLast": "Patel",
        "nameFirst": "Ritesh",
        "name": "Patel, Ritesh"
    },
    {
        "id": "person:pisharody__sandeep",
        "organizations": [
            "MIT"
        ],
        "nameLast": "Pisharody",
        "nameFirst": "Sandeep",
        "name": "Pisharody, Sandeep"
    },
    {
        "id": "person:reuther__albert",
        "organizations": [
            "MIT"
        ],
        "nameLast": "Reuther",
        "nameFirst": "Albert",
        "name": "Reuther, Albert"
    },
    {
        "id": "person:rosa__antonio",
        "organizations": [
            "MIT"
        ],
        "nameLast": "Rosa",
        "nameFirst": "Antonio",
        "name": "Rosa, Antonio"
    },
    {
        "id": "person:samsi__siddharth",
        "organizations": [
            "MIT"
        ],
        "nameLast": "Samsi",
        "nameFirst": "Siddharth",
        "name": "Samsi, Siddharth"
    },
    {
        "id": "person:yee__charles",
        "organizations": [
            "MIT"
        ],
        "nameLast": "Yee",
        "nameFirst": "Charles",
        "name": "Yee, Charles"
    },
    {
        "id": "person:michaleas__peter",
        "organizations": [
            "MIT"
        ],
        "nameLast": "Michaleas",
        "nameFirst": "Peter",
        "name": "Michaleas, Peter"
    }
]

# %%
import os
import json

for person in people:
    filename = f"{person['nameLast'].lower()}__{person['nameFirst'].lower()}.json"
    filepath = os.path.join(directory, filename)
    person['organizations'] = 'Massachusetts Institute of Technology (MIT)'
    
    if not os.path.exists(filepath):
        with open(filepath, 'w') as json_file:
            json.dump(person, json_file, indent=4)
